# %% [markdown]
# # **English Project**
# ### Recognizing images:
#
# *   Neymar;
# *   Cristiano Ronaldo;
# *   Messi.

# %%
! [ -e /content ] & pip install -Uqq fastbook
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 110.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 48.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 83.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 32.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 91.1 MB/s eta 0:00:00

# %%
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# ## **Importing .pkl file**

# %% [markdown]
# Importing the .pkl file that was acquired by [Image Classifier](https://colab.research.google.com/drive/170y_fjNLhk5qOg17GXmKUCDP5HG3EyH-?usp=sharing)

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl')

# %% [markdown]
# # **Creating the GUI with ipywidgets**

# %% [markdown]
# Initializing widgets:

# %%
upload = widgets.FileUpload()
output = widgets.Output()
label = widgets.Label()

# %% [markdown]
# Create an observer that verify the last element of ```upload.data``` and change the output for every new element uploaded:

# %%
def data_change(img_input):
    img = PILImage.create(upload.data[-1])
    output.clear_output()
    with output:
        display(img.to_thumb(256, 256))
    label_pred, index_pred, prob = learn_inf.predict(img)
    label.value = f"Predict: {label_pred} / Confidence: {prob[index_pred]*100:.02f}%"    
upload.observe(data_change, names=['data'])

# %% [markdown]
# # **Uploader (Neymar, Cristiano Ronaldo or Messi)**

# %%
box = widgets.VBox([upload, output, label])
display(box)
# Out:
# VBox(children=(FileUpload(value={}, description='Upload'), Output(), Label(value='')))
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
